# %% [markdown]
# # Packet capture in Python

# %% [markdown]
# ## 1. Packet Description

# %% [markdown]
#  At first, we need to know what the packet and where the packet is. While in Chrome press the F12 key on your keyboard to enter the developer mode of chrome browser. In the developer mode, you can analyze the interaction process between the browser and HTTP server. When you enter developer mode for the first time, you need to press the CTRL+R keys again.

# %% [markdown]
#  Name under the Network Options form indicates the name of the requested resource, Status indicates the status code of the server-side response, and Type indicates the resource type. In the Filter input box, the request object can be filtered, for example, to filter out network requests whose name contains the keyword you wants to get.

# %% [markdown]
# ## 2. Permission Check

# %% [markdown]
#  Almost every website has a document called robots.txt, but some websites do not have robots.txt. For websites that do not have robots.txt, you can get data without password encryption through web crawlers, which means that all pages of the website can be crawled. If the website has robots.txt document, we have to determine whether there is data that is forbidden for visitors to get. For example GitHub, for users who do not have permission, all crawling is disabled, with the following code.

# %%
# If you would like to crawl GitHub contact us via https://support.github.com?tags=dotcom-robots
# We also provide an extensive API: https://docs.github.com
User-agent: baidu
crawl-delay: 1


User-agent: *

Disallow: /*/pulse
Disallow: /*/tree/
Disallow: /gist/
Disallow: /*/forks
Disallow: /*/stars
Disallow: /*/download
Disallow: /*/revisions
Disallow: /*/issues/new
Disallow: /*/issues/search
Disallow: /*/commits/
Disallow: /*/commits/*?author
Disallow: /*/commits/*?path
Disallow: /*/branches
Disallow: /*/tags
Disallow: /*/contributors
Disallow: /*/comments
Disallow: /*/stargazers
Disallow: /*/archive/
Disallow: /*/blame/
Disallow: /*/watchers
Disallow: /*/network
Disallow: /*/graphs
Disallow: /*/raw/
Disallow: /*/compare/
Disallow: /*/cache/
Disallow: /.git/
Disallow: */.git/
Disallow: /*.git$
Disallow: /search/advanced
Disallow: /search
Disallow: */search
Disallow: /*q=
Disallow: /*.atom$

Disallow: /ekansa/Open-Context-Data
Disallow: /ekansa/opencontext-*
Disallow: */tarball/
Disallow: */zipball/

Disallow: /*source=*
Disallow: /*ref_cta=*
Disallow: /*plan=*
Disallow: /*return_to=*
Disallow: /*ref_loc=*
Disallow: /*setup_organization=*
Disallow: /*source_repo=*
Disallow: /*ref_page=*
Disallow: /*source=*
Disallow: /*referrer=*
Disallow: /*report=*
Disallow: /*author=*
Disallow: /*since=*
Disallow: /*until=*
Disallow: /*commits?author=*
Disallow: /*report-abuse?report=*
Disallow: /*tab=*
Allow: /*?tab=achievements&achievement=*

Disallow: /account-login
Disallow: /Explodingstuff/

# %% [markdown]
# ## 3. Basic of packet capture

# %% [markdown]
# The web request process is divided into two parts: Request and Response, just like the way the web request is divided into two types: GET and POST

# %%
#After determining who and how to request
import requests 
url = 'http://www.google.com/'
strhtml = requests.get(url)   
print(strhtml.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta content="Search the world's information, including webpages, images, videos and more. Google has many special features to help you find exactly what you're looking for." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="gQsRcLqK6FKVjCQgTwUsOw">(function(){window.google={kEI:'CYVZY4r8Dda31sQPpfC-uAE',kEXPI:'0,1302536,56873,6059,206,4804,2316,383,246,5,5367,1123753,1197735,156,503,380096,16115,28684,22430,1362,284,12036,17579,4998,13228,3847,10622,22741,2855,2226,887,706,1279,2744,147,561,542,840,1983,214,4100,108,4012,2023,1733,43,521,14670,3228,2844,7,4773,38,28959,1850,15325,432,3,1590,1,5444,149,11323,2652,4,1528,2304,7039,22023,5708,7357,16638,1457,9358,5993,1435,5794,2563,4094,4052,3,3541,1
# ...
